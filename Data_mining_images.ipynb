# %% [markdown]
# <a href="https://colab.research.google.com/github/amchirica/images_class/blob/main/Data_mining_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import os, glob
import pandas as pd
from torch.utils.data import Dataset, random_split, DataLoader

# %%
pip install opendatasets --upgrade
# Out:
# Requirement already satisfied: opendatasets in /usr/local/lib/python3.10/dist-packages (0.1.22)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from opendatasets) (4.66.1)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (from opendatasets) (1.5.16)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from opendatasets) (8.1.7)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2023.11.17)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.31.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (3.6)

# %%
import opendatasets as od
dataset_url = 'https://www.kaggle.com/datasets/andrei08/coil100'
od.download(dataset_url)
# Out:
# Skipping, found downloaded files in "./coil100" (use force=True to force download)

# %%
data_direct = './coil100/coil-100/coil-100'
file_list = glob.glob(f'{data_direct}/*.png')

labels = [(f.split('/')[-1], int(f.split('/')[-1].split('__')[0].split('obj')[1]))   for f in file_list]

# %%
file_list
# Out:
# ['./coil100/coil-100/coil-100/obj14__75.png',
#  './coil100/coil-100/coil-100/obj27__275.png',
#  './coil100/coil-100/coil-100/obj6__325.png',
#  './coil100/coil-100/coil-100/obj21__160.png',
#  './coil100/coil-100/coil-100/obj67__90.png',
#  './coil100/coil-100/coil-100/obj32__85.png',
#  './coil100/coil-100/coil-100/obj31__40.png',
#  './coil100/coil-100/coil-100/obj98__225.png',
#  './coil100/coil-100/coil-100/obj7__105.png',
#  './coil100/coil-100/coil-100/obj17__5.png',
#  './coil100/coil-100/coil-100/obj80__285.png',
#  './coil100/coil-100/coil-100/obj91__110.png',
#  './coil100/coil-100/coil-100/obj66__160.png',
#  './coil100/coil-100/coil-100/obj9__300.png',
#  './coil100/coil-100/coil-100/obj17__150.png',
#  './coil100/coil-100/coil-100/obj60__235.png',
#  './coil100/coil-100/coil-100/obj96__120.png',
#  './coil100/coil-100/coil-100/obj33__315.png',
#  './coil100/coil-100/coil-100/obj56__160.png',
#  './coil100/coil-100/coil-100/obj23__255.png',
#  './coil100/coil-100/coil-100/obj93__10.png',
#  './coil100/coil-100/coil-100/obj22__45.png',
#  './coil100/coil-100/coil-100/obj78__270.png',
#  './coil100/coil-100/coil-100/obj55__190.png',
#  './coil100/coil-100/coil-100/obj90__320.png',
#  './coil100/coil-100/coil-100/obj67__355.png',
#  './coil100/coil-100/coil-100/obj7__150.png',
#  './coil100/coil-100/coil-100/obj53__110.png',
#  './coil100/coil-100/coil-100/obj63__105.png',
#  './coil100/coil-100/coil-100/obj75__335.png',
#  './coil100/coil-100/coil-100/obj47__215.png',
#  './coil100/coil-100/coil-100/obj87__140.png',
#  './coil100/coil-100/coil-100/obj85__270.png',
#  './coil100/coil-100/coil-100/obj32__50.png',
#  './coil100/coil-100/coil-100/obj7__100.png',
#  './coil100/coil-100/coil-100/obj73__100.png',
#  './coil100/coil-100/coil-100/obj1__140.png',
#  './coil100/coil-100/coil-100/obj88__190.png',
#  './coil100/coil-100/coil-100/obj37__30.png',
#  './coil100/coil-100/coil-100/obj37__65.png',
#  './coil100/coil-100/coil-100/obj11__15.png',
#  './coil100/coil-100/coil-100/obj87__10.png',
#  './coil100/coil-100/coil-100/obj58__140.png',
#  './coil100/coil-100/coil-100/obj34__220.png',
#  './coil100/coil-100/coil-100/obj8__80.png',
#  './coil100/coil-100/coil-100/obj55__125.png',
#  './coil100/coil-100/coil-100/obj39__255.png',
#  './coil100/coil-100/coil-100/obj95__120.png',
#  './coil100/coil-100/coil-100/obj68__10.png',
#  './coil100/coil-100/coil-100/obj55__320.png',
#  './coil100/coil-100/coil-100/obj13__15.png',
#  './coil100/coil-100/coil-100/obj37__205.png',
#  './coil100/coil-100/coil-100/obj56__175.png',
#  './coil100/coil-100/coil-100/obj86__75.png',
#  './coil100/coil-100/coil-100/obj39__270.png',
#  './coil100/coil-100/coil-100/obj22__140.png',
#  './coil100/coil-100/coil-100/obj95__0.png',
#  './coil100/coil-100/coil-100/obj43__105.png',
#  './coil100/coil-100/coil-100/obj100__275.png',
#  './coil100/coil-100/coil-100/obj43__225.png',
#  './coil100/coil-100/coil-100/obj64__175.png',
#  './coil100/coil-100/coil-100/obj21__110.png',
#  './coil100/coil-100/coil-100/obj64__225.png',
#  './coil100/coil-100/coil-100/obj4__150.png',
#  './coil100/coil-100/coil-100/obj98__335.png',
#  './coil100/coil-100/coil-100/obj71__115.png',
#  './coil100/coil-100/coil-100/obj1__215.png',
#  './coil100/coil-100/coil-100/obj89__110.png',
#  './coil100/coil-100/coil-100/obj24__105.png',
#  './coil100/coil-100/coil-100/obj77__300.png',
#  './coil100/coil-100/coil-100/obj35__0.png',
#  './coil100/coil-100/coil-100/obj63__55.png',
#  './coil100/coil-100/coil-100/obj12__315.png',
#  './coil100/coil-100/coil-100/obj25__290.png',
#  './coil100/coil-100/coil-100/obj81__20.png',
#  './coil100/coil-100/coil-100/obj54__230.png',
#  './coil100/coil-100/coil-100/obj4__215.png',
#  './coil100/coil-100/coil-100/obj8__5.png',
#  './coil100/coil-100/coil-100/obj74__210.png',
#  './coil100/coil-100/coil-100/obj35__175.png',
#  './coil100/coil-100/coil-100/obj8__230.png',
#  './coil100/coil-100/coil-100/obj100__65.png',
#  './coil100/coil-100/coil-100/obj85__205.png',
#  './coil100/coil-100/coil-100/obj71__70.png',
#  './coil100/coil-100/coil-100/obj32__285.png',
#  './coil100/coil-100/coil-100/obj51__175.png',
#  './coil100/coil-100/coil-100/obj47__45.png',
#  './coil100/coil-100/coil-100/obj84__305.png',
#  './coil100/coil-100/coil-100/obj23__200.png',
#  './coil100/coil-100/coil-100/obj91__70.png',
#  './coil100/coil-100/coil-100/obj51__20.png',
#  './coil100/coil-100/coil-100/obj74__175.png',
#  './coil100/coil-100/coil-100/obj25__110.png',
#  './coil100/coil-100/coil-100/obj58__215.png',
#  './coil100/coil-100/coil-100/obj97__65.png',
#  './coil100/coil-100/coil-100/obj3__295.png',
#  './coil100/coil-100/coil-100/obj84__330.png',
#  './coil100/coil-100/coil-100/obj2__115.png',
#  './coil100/coil-100/coil-100/obj39__90.png',
#  './coil100/coil-100/coil-100/obj94__260.png',
#  './coil100/coil-100/coil-100/obj29__85.png',
#  './coil100/coil-100/coil-100/obj56__20.png',
#  './coil100/coil-100/coil-100/obj5__200.png',
#  './coil100/coil-100/coil-100/obj62__310.png',
#  './coil100/coil-100/coil-100/obj39__10.png',
#  './coil100/coil-100/coil-100/obj56__140.png',
#  './coil100/coil-100/coil-100/obj54__95.png',
#  './coil100/coil-100/coil-100/obj80__195.png',
#  './coil100/coil-100/coil-100/obj56__315.png',
#  './coil100/coil-100/coil-100/obj74__270.png',
#  './coil100/coil-100/coil-100/obj37__60.png',
#  './coil100/coil-100/coil-100/obj26__215.png',
#  './coil100/coil-100/coil-100/obj73__315.png',
#  './coil100/coil-100/coil-100/obj88__15.png',
#  './coil100/coil-100/coil-100/obj11__135.png',
#  './coil100/coil-100/coil-100/obj2__80.png',
#  './coil100/coil-100/coil-100/obj22__30.png',
#  './coil100/coil-100/coil-100/obj27__130.png',
#  './coil100/coil-100/coil-100/obj41__5.png',
#  './coil100/coil-100/coil-100/obj24__30.png',
#  './coil100/coil-100/coil-100/obj8__170.png',
#  './coil100/coil-100/coil-100/obj17__120.png',
#  './coil100/coil-100/coil-100/obj100__185.png',
#  './coil100/coil-100/coil-100/obj35__325.png',
#  './coil100/coil-100/coil-100/obj39__335.png',
#  './coil100/coil-100/coil-100/obj83__80.png',
#  './coil100/coil-100/coil-100/obj46__95.png',
#  './coil100/coil-100/coil-100/obj35__210.png',
#  './coil100/coil-100/coil-100/obj26__295.png',
#  './coil100/coil-100/coil-100/obj55__305.png',
#  './coil100/coil-100/coil-100/obj54__225.png',
#  './coil100/coil-100/coil-100/obj23__120.png',
#  './coil100/coil-100/coil-100/obj45__55.png',
#  './coil100/coil-100/coil-100/obj7__180.png',
#  './coil100/coil-100/coil-100/obj4__165.png',
#  './coil100/coil-100/coil-100/obj38__25.png',
#  './coil100/coil-100/coil-100/obj70__85.png',
#  './coil100/coil-100/coil-100/obj77__5.png',
#  './coil100/coil-100/coil-100/obj59__5.png',
#  './coil100/coil-100/coil-100/obj2__60.png',
#  './coil100/coil-100/coil-100/obj61__25.png',
#  './coil100/coil-100/coil-100/obj94__15.png',
#  './coil100/coil-100/coil-100/obj39__170.png',
#  './coil100/coil-100/coil-100/obj12__135.png',
#  './coil100/coil-100/coil-100/obj71__250.png',
#  './coil100/coil-100/coil-100/obj75__345.png',
#  './coil100/coil-100/coil-100/obj59__75.png',
#  './coil100/coil-100/coil-100/obj50__0.png',
#  './coil100/coil-100/coil-100/obj25__35.png',
#  './coil100/coil-100/coil-100/obj40__165.png',
#  './coil100/coil-100/coil-100/obj51__110.png',
#  './coil100/coil-100/coil-100/obj69__25.png',
#  './coil100/coil-100/coil-100/obj11__280.png',
#  './coil100/coil-100/coil-100/obj99__170.png',
#  './coil100/coil-100/coil-100/obj39__250.png',
#  './coil100/coil-100/coil-100/obj85__335.png',
#  './coil100/coil-100/coil-100/obj86__30.png',
#  './coil100/coil-100/coil-100/obj85__320.png',
#  './coil100/coil-100/coil-100/obj92__220.png',
#  './coil100/coil-100/coil-100/obj74__70.png',
#  './coil100/coil-100/coil-100/obj75__90.png',
#  './coil100/coil-100/coil-100/obj31__185.png',
#  './coil100/coil-100/coil-100/obj25__280.png',
#  './coil100/coil-100/coil-100/obj81__355.png',
#  './coil100/coil-100/coil-100/obj1__10.png',
#  './coil100/coil-100/coil-100/obj62__305.png',
#  './coil100/coil-100/coil-100/obj77__260.png',
#  './coil100/coil-100/coil-100/obj35__55.png',
#  './coil100/coil-100/coil-100/obj24__215.png',
#  './coil100/coil-100/coil-100/obj23__180.png',
#  './coil100/coil-100/coil-100/obj87__165.png',
#  './coil100/coil-100/coil-100/obj74__255.png',
#  './coil100/coil-100/coil-100/obj18__105.png',
#  './coil100/coil-100/coil-100/obj12__330.png',
#  './coil100/coil-100/coil-100/obj50__220.png',
#  './coil100/coil-100/coil-100/obj16__110.png',
#  './coil100/coil-100/coil-100/obj83__25.png',
#  './coil100/coil-100/coil-100/obj54__140.png',
#  './coil100/coil-100/coil-100/obj20__55.png',
#  './coil100/coil-100/coil-100/obj71__15.png',
#  './coil100/coil-100/coil-100/obj64__105.png',
#  './coil100/coil-100/coil-100/obj20__65.png',
#  './coil100/coil-100/coil-100/obj57__245.png',
#  './coil100/coil-100/coil-100/obj20__50.png',
#  './coil100/coil-100/coil-100/obj38__325.png',
#  './coil100/coil-100/coil-100/obj63__110.png',
#  './coil100/coil-100/coil-100/obj78__15.png',
#  './coil100/coil-100/coil-100/obj41__205.png',
#  './coil100/coil-100/coil-100/obj40__0.png',
#  './coil100/coil-100/coil-100/obj84__180.png',
#  './coil100/coil-100/coil-100/obj22__160.png',
#  './coil100/coil-100/coil-100/obj17__320.png',
#  './coil100/coil-100/coil-100/obj30__115.png',
#  './coil100/coil-100/coil-100/obj56__280.png',
#  './coil100/coil-100/coil-100/obj78__295.png',
#  './coil100/coil-100/coil-100/obj26__65.png',
#  './coil100/coil-100/coil-100/obj19__250.png',
#  './coil100/coil-100/coil-100/obj21__25.png',
#  './coil100/coil-100/coil-100/obj93__340.png',
#  './coil100/coil-100/coil-100/obj93__295.png',
#  './coil100/coil-100/coil-100/obj64__170.png',
#  './coil100/coil-100/coil-100/obj28__220.png',
#  './coil100/coil-100/coil-100/obj74__105.png',
#  './coil100/coil-100/coil-100/obj46__335.png',
#  './coil100/coil-100/coil-100/obj65__175.png',
#  './coil100/coil-100/coil-100/obj55__80.png',
#  './coil100/coil-100/coil-100/obj76__355.png',
#  './coil100/coil-100/coil-100/obj74__125.png',
#  './coil100/coil-100/coil-100/obj7__55.png',
#  './coil100/coil-100/coil-100/obj71__320.png',
#  './coil100/coil-100/coil-100/obj30__225.png',
#  './coil100/coil-100/coil-100/obj48__15.png',
#  './coil100/coil-100/coil-100/obj62__75.png',
#  './coil100/coil-100/coil-100/obj46__300.png',
#  './coil100/coil-100/coil-100/obj52__165.png',
#  './coil100/coil-100/coil-100/obj50__200.png',
#  './coil100/coil-100/coil-100/obj84__230.png',
#  './coil100/coil-100/coil-100/obj97__225.png',
#  './coil100/coil-100/coil-100/obj44__40.png',
#  './coil100/coil-100/coil-100/obj69__205.png',
#  './coil100/coil-100/coil-100/obj70__30.png',
#  './coil100/coil-100/coil-100/obj92__205.png',
#  './coil100/coil-100/coil-100/obj95__105.png',
#  './coil100/coil-100/coil-100/obj27__290.png',
#  './coil100/coil-100/coil-100/obj76__110.png',
#  './coil100/coil-100/coil-100/obj43__145.png',
#  './coil100/coil-100/coil-100/obj49__355.png',
#  './coil100/coil-100/coil-100/obj75__290.png',
#  './coil100/coil-100/coil-100/obj68__75.png',
#  './coil100/coil-100/coil-100/obj61__95.png',
#  './coil100/coil-100/coil-100/obj90__135.png',
#  './coil100/coil-100/coil-100/obj40__260.png',
#  './coil100/coil-100/coil-100/obj85__10.png',
#  './coil100/coil-100/coil-100/obj50__65.png',
#  './coil100/coil-100/coil-100/obj36__70.png',
#  './coil100/coil-100/coil-100/obj2__25.png',
#  './coil100/coil-100/coil-100/obj72__325.png',
#  './coil100/coil-100/coil-100/obj96__330.png',
#  './coil100/coil-100/coil-100/obj79__125.png',
#  './coil100/coil-100/coil-100/obj75__255.png',
#  './coil100/coil-100/coil-100/obj81__130.png',
#  './coil100/coil-100/coil-100/obj11__105.png',
#  './coil100/coil-100/coil-100/obj47__165.png',
#  './coil100/coil-100/coil-100/obj62__210.png',
#  './coil100/coil-100/coil-100/obj25__195.png',
#  './coil100/coil-100/coil-100/obj22__175.png',
#  './coil100/coil-100/coil-100/obj61__220.png',
#  './coil100/coil-100/coil-100/obj100__330.png',
#  './coil100/coil-100/coil-100/obj45__110.png',
#  './coil100/coil-100/coil-100/obj63__150.png',
#  './coil100/coil-100/coil-100/obj82__335.png',
#  './coil100/coil-100/coil-100/obj15__345.png',
#  './coil100/coil-100/coil-100/obj63__205.png',
#  './coil100/coil-100/coil-100/obj35__50.png',
#  './coil100/coil-100/coil-100/obj63__250.png',
#  './coil100/coil-100/coil-100/obj19__155.png',
#  './coil100/coil-100/coil-100/obj17__215.png',
#  './coil100/coil-100/coil-100/obj11__50.png',
#  './coil100/coil-100/coil-100/obj64__285.png',
#  './coil100/coil-100/coil-100/obj95__245.png',
#  './coil100/coil-100/coil-100/obj68__355.png',
#  './coil100/coil-100/coil-100/obj20__285.png',
#  './coil100/coil-100/coil-100/obj63__0.png',
#  './coil100/coil-100/coil-100/obj36__15.png',
#  './coil100/coil-100/coil-100/obj73__140.png',
#  './coil100/coil-100/coil-100/obj35__255.png',
#  './coil100/coil-100/coil-100/obj92__350.png',
#  './coil100/coil-100/coil-100/obj51__215.png',
#  './coil100/coil-100/coil-100/obj33__40.png',
#  './coil100/coil-100/coil-100/obj86__110.png',
#  './coil100/coil-100/coil-100/obj27__65.png',
#  './coil100/coil-100/coil-100/obj54__345.png',
#  './coil100/coil-100/coil-100/obj89__75.png',
#  './coil100/coil-100/coil-100/obj87__240.png',
#  './coil100/coil-100/coil-100/obj79__340.png',
#  './coil100/coil-100/coil-100/obj81__135.png',
#  './coil100/coil-100/coil-100/obj57__65.png',
#  './coil100/coil-100/coil-100/obj97__160.png',
#  './coil100/coil-100/coil-100/obj25__20.png',
#  './coil100/coil-100/coil-100/obj67__140.png',
#  './coil100/coil-100/coil-100/obj4__350.png',
#  './coil100/coil-100/coil-100/obj60__120.png',
#  './coil100/coil-100/coil-100/obj32__175.png',
#  './coil100/coil-100/coil-100/obj1__110.png',
#  './coil100/coil-100/coil-100/obj80__225.png',
#  './coil100/coil-100/coil-100/obj77__355.png',
#  './coil100/coil-100/coil-100/obj97__330.png',
#  './coil100/coil-100/coil-100/obj16__120.png',
#  './coil100/coil-100/coil-100/obj34__255.png',
#  './coil100/coil-100/coil-100/obj42__230.png',
#  './coil100/coil-100/coil-100/obj29__300.png',
#  './coil100/coil-100/coil-100/obj61__330.png',
#  './coil100/coil-100/coil-100/obj76__345.png',
#  './coil100/coil-100/coil-100/obj22__320.png',
#  './coil100/coil-100/coil-100/obj3__95.png',
#  './coil100/coil-100/coil-100/obj88__45.png',
#  './coil100/coil-100/coil-100/obj50__130.png',
#  './coil100/coil-100/coil-100/obj99__275.png',
#  './coil100/coil-100/coil-100/obj51__75.png',
#  './coil100/coil-100/coil-100/obj45__265.png',
#  './coil100/coil-100/coil-100/obj78__355.png',
#  './coil100/coil-100/coil-100/obj10__75.png',
#  './coil100/coil-100/coil-100/obj62__20.png',
#  './coil100/coil-100/coil-100/obj11__70.png',
#  './coil100/coil-100/coil-100/obj68__255.png',
#  './coil100/coil-100/coil-100/obj50__160.png',
#  './coil100/coil-100/coil-100/obj41__90.png',
#  './coil100/coil-100/coil-100/obj40__325.png',
#  './coil100/coil-100/coil-100/obj94__100.png',
#  './coil100/coil-100/coil-100/obj82__0.png',
#  './coil100/coil-100/coil-100/obj34__35.png',
#  './coil100/coil-100/coil-100/obj80__255.png',
#  './coil100/coil-100/coil-100/obj38__220.png',
#  './coil100/coil-100/coil-100/obj83__220.png',
#  './coil100/coil-100/coil-100/obj87__85.png',
#  './coil100/coil-100/coil-100/obj33__300.png',
#  './coil100/coil-100/coil-100/obj62__0.png',
#  './coil100/coil-100/coil-100/obj33__190.png',
#  './coil100/coil-100/coil-100/obj38__305.png',
#  './coil100/coil-100/coil-100/obj96__280.png',
#  './coil100/coil-100/coil-100/obj82__130.png',
#  './coil100/coil-100/coil-100/obj44__10.png',
#  './coil100/coil-100/coil-100/obj35__335.png',
#  './coil100/coil-100/coil-100/obj43__170.png',
#  './coil100/coil-100/coil-100/obj66__275.png',
#  './coil100/coil-100/coil-100/obj79__85.png',
#  './coil100/coil-100/coil-100/obj83__105.png',
#  './coil100/coil-100/coil-100/obj80__220.png',
#  './coil100/coil-100/coil-100/obj91__10.png',
#  './coil100/coil-100/coil-100/obj23__80.png',
#  './coil100/coil-100/coil-100/obj85__65.png',
#  './coil100/coil-100/coil-100/obj16__315.png',
#  './coil100/coil-100/coil-100/obj50__275.png',
#  './coil100/coil-100/coil-100/obj65__350.png',
#  './coil100/coil-100/coil-100/obj47__230.png',
#  './coil100/coil-100/coil-100/obj34__325.png',
#  './coil100/coil-100/coil-100/obj71__60.png',
#  './coil100/coil-100/coil-100/obj60__155.png',
#  './coil100/coil-100/coil-100/obj9__130.png',
#  './coil100/coil-100/coil-100/obj28__215.png',
#  './coil100/coil-100/coil-100/obj44__215.png',
#  './coil100/coil-100/coil-100/obj16__230.png',
#  './coil100/coil-100/coil-100/obj33__125.png',
#  './coil100/coil-100/coil-100/obj21__255.png',
#  './coil100/coil-100/coil-100/obj16__215.png',
#  './coil100/coil-100/coil-100/obj25__240.png',
#  './coil100/coil-100/coil-100/obj39__310.png',
#  './coil100/coil-100/coil-100/obj33__340.png',
#  './coil100/coil-100/coil-100/obj96__25.png',
#  './coil100/coil-100/coil-100/obj55__200.png',
#  './coil100/coil-100/coil-100/obj77__150.png',
#  './coil100/coil-100/coil-100/obj66__55.png',
#  './coil100/coil-100/coil-100/obj81__245.png',
#  './coil100/coil-100/coil-100/obj94__285.png',
#  './coil100/coil-100/coil-100/obj79__120.png',
#  './coil100/coil-100/coil-100/obj83__55.png',
#  './coil100/coil-100/coil-100/obj95__90.png',
#  './coil100/coil-100/coil-100/obj11__5.png',
#  './coil100/coil-100/coil-100/obj74__300.png',
#  './coil100/coil-100/coil-100/obj2__250.png',
#  './coil100/coil-100/coil-100/obj21__40.png',
#  './coil100/coil-100/coil-100/obj97__80.png',
#  './coil100/coil-100/coil-100/obj70__115.png',
#  './coil100/coil-100/coil-100/obj75__0.png',
#  './coil100/coil-100/coil-100/obj56__35.png',
#  './coil100/coil-100/coil-100/obj49__185.png',
#  './coil100/coil-100/coil-100/obj5__335.png',
#  './coil100/coil-100/coil-100/obj99__320.png',
#  './coil100/coil-100/coil-100/obj59__140.png',
#  './coil100/coil-100/coil-100/obj2__215.png',
#  './coil100/coil-100/coil-100/obj39__95.png',
#  './coil100/coil-100/coil-100/obj47__280.png',
#  './coil100/coil-100/coil-100/obj67__180.png',
#  './coil100/coil-100/coil-100/obj13__220.png',
#  './coil100/coil-100/coil-100/obj95__290.png',
#  './coil100/coil-100/coil-100/obj73__300.png',
#  './coil100/coil-100/coil-100/obj30__50.png',
#  './coil100/coil-100/coil-100/obj41__150.png',
#  './coil100/coil-100/coil-100/obj8__20.png',
#  './coil100/coil-100/coil-100/obj28__280.png',
#  './coil100/coil-100/coil-100/obj79__265.png',
#  './coil100/coil-100/coil-100/obj60__145.png',
#  './coil100/coil-100/coil-100/obj100__30.png',
#  './coil100/coil-100/coil-100/obj73__35.png',
#  './coil100/coil-100/coil-100/obj99__325.png',
#  './coil100/coil-100/coil-100/obj47__130.png',
#  './coil100/coil-100/coil-100/obj74__215.png',
#  './coil100/coil-100/coil-100/obj43__95.png',
#  './coil100/coil-100/coil-100/obj70__40.png',
#  './coil100/coil-100/coil-100/obj6__210.png',
#  './coil100/coil-100/coil-100/obj70__245.png',
#  './coil100/coil-100/coil-100/obj19__50.png',
#  './coil100/coil-100/coil-100/obj2__245.png',
#  './coil100/coil-100/coil-100/obj3__175.png',
#  './coil100/coil-100/coil-100/obj68__135.png',
#  './coil100/coil-100/coil-100/obj23__35.png',
#  './coil100/coil-100/coil-100/obj94__355.png',
#  './coil100/coil-100/coil-100/obj25__205.png',
#  './coil100/coil-100/coil-100/obj79__20.png',
#  './coil100/coil-100/coil-100/obj57__225.png',
#  './coil100/coil-100/coil-100/obj32__255.png',
#  './coil100/coil-100/coil-100/obj92__170.png',
#  './coil100/coil-100/coil-100/obj27__10.png',
#  './coil100/coil-100/coil-100/obj81__5.png',
#  './coil100/coil-100/coil-100/obj35__45.png',
#  './coil100/coil-100/coil-100/obj65__10.png',
#  './coil100/coil-100/coil-100/obj26__355.png',
#  './coil100/coil-100/coil-100/obj81__110.png',
#  './coil100/coil-100/coil-100/obj55__115.png',
#  './coil100/coil-100/coil-100/obj54__235.png',
#  './coil100/coil-100/coil-100/obj35__190.png',
#  './coil100/coil-100/coil-100/obj49__190.png',
#  './coil100/coil-100/coil-100/obj33__10.png',
#  './coil100/coil-100/coil-100/obj98__5.png',
#  './coil100/coil-100/coil-100/obj77__290.png',
#  './coil100/coil-100/coil-100/obj1__125.png',
#  './coil100/coil-100/coil-100/obj97__140.png',
#  './coil100/coil-100/coil-100/obj85__25.png',
#  './coil100/coil-100/coil-100/obj65__300.png',
#  './coil100/coil-100/coil-100/obj95__355.png',
#  './coil100/coil-100/coil-100/obj55__35.png',
#  './coil100/coil-100/coil-100/obj55__230.png',
#  './coil100/coil-100/coil-100/obj7__295.png',
#  './coil100/coil-100/coil-100/obj83__165.png',
#  './coil100/coil-100/coil-100/obj77__340.png',
#  './coil100/coil-100/coil-100/obj1__220.png',
#  './coil100/coil-100/coil-100/obj58__100.png',
#  './coil100/coil-100/coil-100/obj3__215.png',
#  './coil100/coil-100/coil-100/obj67__185.png',
#  './coil100/coil-100/coil-100/obj38__60.png',
#  './coil100/coil-100/coil-100/obj59__175.png',
#  './coil100/coil-100/coil-100/obj76__240.png',
#  './coil100/coil-100/coil-100/obj85__245.png',
#  './coil100/coil-100/coil-100/obj35__155.png',
#  './coil100/coil-100/coil-100/obj2__355.png',
#  './coil100/coil-100/coil-100/obj99__315.png',
#  './coil100/coil-100/coil-100/obj3__160.png',
#  './coil100/coil-100/coil-100/obj32__215.png',
#  './coil100/coil-100/coil-100/obj46__90.png',
#  './coil100/coil-100/coil-100/obj31__140.png',
#  './coil100/coil-100/coil-100/obj8__225.png',
#  './coil100/coil-100/coil-100/obj14__270.png',
#  './coil100/coil-100/coil-100/obj93__40.png',
#  './coil100/coil-100/coil-100/obj26__85.png',
#  './coil100/coil-100/coil-100/obj2__0.png',
#  './coil100/coil-100/coil-100/obj95__320.png',
#  './coil100/coil-100/coil-100/obj34__165.png',
#  './coil100/coil-100/coil-100/obj58__260.png',
#  './coil100/coil-100/coil-100/obj64__195.png',
#  './coil100/coil-100/coil-100/obj56__70.png',
#  './coil100/coil-100/coil-100/obj62__330.png',
#  './coil100/coil-100/coil-100/obj54__315.png',
#  './coil100/coil-100/coil-100/obj97__40.png',
#  './coil100/coil-100/coil-100/obj15__230.png',
#  './coil100/coil-100/coil-100/obj22__350.png',
#  './coil100/coil-100/coil-100/obj35__330.png',
#  './coil100/coil-100/coil-100/obj58__0.png',
#  './coil100/coil-100/coil-100/obj5__115.png',
#  './coil100/coil-100/coil-100/obj32__170.png',
#  './coil100/coil-100/coil-100/obj49__115.png',
#  './coil100/coil-100/coil-100/obj23__170.png',
#  './coil100/coil-100/coil-100/obj2__255.png',
#  './coil100/coil-100/coil-100/obj42__355.png',
#  './coil100/coil-100/coil-100/obj23__30.png',
#  './coil100/coil-100/coil-100/obj24__235.png',
#  './coil100/coil-100/coil-100/obj10__235.png',
#  './coil100/coil-100/coil-100/obj12__140.png',
#  './coil100/coil-100/coil-100/obj87__345.png',
#  './coil100/coil-100/coil-100/obj16__100.png',
#  './coil100/coil-100/coil-100/obj4__220.png',
#  './coil100/coil-100/coil-100/obj55__170.png',
#  './coil100/coil-100/coil-100/obj8__130.png',
#  './coil100/coil-100/coil-100/obj48__305.png',
#  './coil100/coil-100/coil-100/obj80__110.png',
#  './coil100/coil-100/coil-100/obj86__135.png',
#  './coil100/coil-100/coil-100/obj59__240.png',
#  './coil100/coil-100/coil-100/obj42__95.png',
#  './coil100/coil-100/coil-100/obj57__300.png',
#  './coil100/coil-100/coil-100/obj22__250.png',
#  './coil100/coil-100/coil-100/obj64__65.png',
#  './coil100/coil-100/coil-100/obj54__40.png',
#  './coil100/coil-100/coil-100/obj73__280.png',
#  './coil100/coil-100/coil-100/obj76__335.png',
#  './coil100/coil-100/coil-100/obj31__320.png',
#  './coil100/coil-100/coil-100/obj83__20.png',
#  './coil100/coil-100/coil-100/obj71__340.png',
#  './coil100/coil-100/coil-100/obj82__240.png',
#  './coil100/coil-100/coil-100/obj70__25.png',
#  './coil100/coil-100/coil-100/obj40__60.png',
#  './coil100/coil-100/coil-100/obj39__260.png',
#  './coil100/coil-100/coil-100/obj98__120.png',
#  './coil100/coil-100/coil-100/obj47__260.png',
#  './coil100/coil-100/coil-100/obj70__15.png',
#  './coil100/coil-100/coil-100/obj1__180.png',
#  './coil100/coil-100/coil-100/obj6__295.png',
#  './coil100/coil-100/coil-100/obj29__265.png',
#  './coil100/coil-100/coil-100/obj54__35.png',
#  './coil100/coil-100/coil-100/obj91__270.png',
#  './coil100/coil-100/coil-100/obj11__285.png',
#  './coil100/coil-100/coil-100/obj7__20.png',
#  './coil100/coil-100/coil-100/obj22__345.png',
#  './coil100/coil-100/coil-100/obj91__255.png',
#  './coil100/coil-100/coil-100/obj76__35.png',
#  './coil100/coil-100/coil-100/obj10__250.png',
#  './coil100/coil-100/coil-100/obj19__35.png',
#  './coil100/coil-100/coil-100/obj90__350.png',
#  './coil100/coil-100/coil-100/obj26__285.png',
#  './coil100/coil-100/coil-100/obj75__145.png',
#  './coil100/coil-100/coil-100/obj11__115.png',
#  './coil100/coil-100/coil-100/obj50__155.png',
#  './coil100/coil-100/coil-100/obj34__185.png',
#  './coil100/coil-100/coil-100/obj94__60.png',
#  './coil100/coil-100/coil-100/obj11__20.png',
#  './coil100/coil-100/coil-100/obj50__250.png',
#  './coil100/coil-100/coil-100/obj87__20.png',
#  './coil100/coil-100/coil-100/obj67__120.png',
#  './coil100/coil-100/coil-100/obj74__120.png',
#  './coil100/coil-100/coil-100/obj8__285.png',
#  './coil100/coil-100/coil-100/obj35__265.png',
#  './coil100/coil-100/coil-100/obj6__305.png',
#  './coil100/coil-100/coil-100/obj88__255.png',
#  './coil100/coil-100/coil-100/obj89__130.png',
#  './coil100/coil-100/coil-100/obj24__5.png',
#  './coil100/coil-100/coil-100/obj47__225.png',
#  './coil100/coil-100/coil-100/obj73__245.png',
#  './coil100/coil-100/coil-100/obj57__90.png',
#  './coil100/coil-100/coil-100/obj3__305.png',
#  './coil100/coil-100/coil-100/obj82__250.png',
#  './coil100/coil-100/coil-100/obj83__280.png',
#  './coil100/coil-100/coil-100/obj47__350.png',
#  './coil100/coil-100/coil-100/obj29__105.png',
#  './coil100/coil-100/coil-100/obj2__285.png',
#  './coil100/coil-100/coil-100/obj72__210.png',
#  './coil100/coil-100/coil-100/obj51__145.png',
#  './coil100/coil-100/coil-100/obj86__140.png',
#  './coil100/coil-100/coil-100/obj32__300.png',
#  './coil100/coil-100/coil-100/obj21__235.png',
#  './coil100/coil-100/coil-100/obj70__320.png',
#  './coil100/coil-100/coil-100/obj46__50.png',
#  './coil100/coil-100/coil-100/obj63__330.png',
#  './coil100/coil-100/coil-100/obj5__0.png',
#  './coil100/coil-100/coil-100/obj58__120.png',
#  './coil100/coil-100/coil-100/obj64__160.png',
#  './coil100/coil-100/coil-100/obj38__75.png',
#  './coil100/coil-100/coil-100/obj59__180.png',
#  './coil100/coil-100/coil-100/obj6__110.png',
#  './coil100/coil-100/coil-100/obj92__60.png',
#  './coil100/coil-100/coil-100/obj11__165.png',
#  './coil100/coil-100/coil-100/obj21__120.png',
#  './coil100/coil-100/coil-100/obj40__200.png',
#  './coil100/coil-100/coil-100/obj62__250.png',
#  './coil100/coil-100/coil-100/obj21__295.png',
#  './coil100/coil-100/coil-100/obj52__15.png',
#  './coil100/coil-100/coil-100/obj46__305.png',
#  './coil100/coil-100/coil-100/obj83__355.png',
#  './coil100/coil-100/coil-100/obj60__210.png',
#  './coil100/coil-100/coil-100/obj87__80.png',
#  './coil100/coil-100/coil-100/obj55__335.png',
#  './coil100/coil-100/coil-100/obj11__270.png',
#  './coil100/coil-100/coil-100/obj73__190.png',
#  './coil100/coil-100/coil-100/obj56__220.png',
#  './coil100/coil-100/coil-100/obj17__125.png',
#  './coil100/coil-100/coil-100/obj67__335.png',
#  './coil100/coil-100/coil-100/obj37__215.png',
#  './coil100/coil-100/coil-100/obj78__345.png',
#  './coil100/coil-100/coil-100/obj21__240.png',
#  './coil100/coil-100/coil-100/obj75__10.png',
#  './coil100/coil-100/coil-100/obj61__350.png',
#  './coil100/coil-100/coil-100/obj40__110.png',
#  './coil100/coil-100/coil-100/obj37__150.png',
#  './coil100/coil-100/coil-100/obj97__5.png',
#  './coil100/coil-100/coil-100/obj57__75.png',
#  './coil100/coil-100/coil-100/obj7__335.png',
#  './coil100/coil-100/coil-100/obj79__210.png',
#  './coil100/coil-100/coil-100/obj50__330.png',
#  './coil100/coil-100/coil-100/obj82__120.png',
#  './coil100/coil-100/coil-100/obj30__300.png',
#  './coil100/coil-100/coil-100/obj58__45.png',
#  './coil100/coil-100/coil-100/obj10__200.png',
#  './coil100/coil-100/coil-100/obj99__35.png',
#  './coil100/coil-100/coil-100/obj43__45.png',
#  './coil100/coil-100/coil-100/obj62__320.png',
#  './coil100/coil-100/coil-100/obj27__320.png',
#  './coil100/coil-100/coil-100/obj4__300.png',
#  './coil100/coil-100/coil-100/obj28__125.png',
#  './coil100/coil-100/coil-100/obj51__100.png',
#  './coil100/coil-100/coil-100/obj73__5.png',
#  './coil100/coil-100/coil-100/obj7__175.png',
#  './coil100/coil-100/coil-100/obj40__225.png',
#  './coil100/coil-100/coil-100/obj75__305.png',
#  './coil100/coil-100/coil-100/obj57__340.png',
#  './coil100/coil-100/coil-100/obj78__275.png',
#  './coil100/coil-100/coil-100/obj63__260.png',
#  './coil100/coil-100/coil-100/obj30__65.png',
#  './coil100/coil-100/coil-100/obj9__190.png',
#  './coil100/coil-100/coil-100/obj63__85.png',
#  './coil100/coil-100/coil-100/obj2__205.png',
#  './coil100/coil-100/coil-100/obj97__105.png',
#  './coil100/coil-100/coil-100/obj1__40.png',
#  './coil100/coil-100/coil-100/obj46__150.png',
#  './coil100/coil-100/coil-100/obj65__335.png',
#  './coil100/coil-100/coil-100/obj11__60.png',
#  './coil100/coil-100/coil-100/obj67__105.png',
#  './coil100/coil-100/coil-100/obj78__265.png',
#  './coil100/coil-100/coil-100/obj96__100.png',
#  './coil100/coil-100/coil-100/obj58__15.png',
#  './coil100/coil-100/coil-100/obj50__170.png',
#  './coil100/coil-100/coil-100/obj27__255.png',
#  './coil100/coil-100/coil-100/obj100__340.png',
#  './coil100/coil-100/coil-100/obj29__195.png',
#  './coil100/coil-100/coil-100/obj71__10.png',
#  './coil100/coil-100/coil-100/obj99__345.png',
#  './coil100/coil-100/coil-100/obj92__260.png',
#  './coil100/coil-100/coil-100/obj56__125.png',
#  './coil100/coil-100/coil-100/obj77__155.png',
#  './coil100/coil-100/coil-100/obj93__230.png',
#  './coil100/coil-100/coil-100/obj20__95.png',
#  './coil100/coil-100/coil-100/obj31__65.png',
#  './coil100/coil-100/coil-100/obj65__330.png',
#  './coil100/coil-100/coil-100/obj91__250.png',
#  './coil100/coil-100/coil-100/obj76__85.png',
#  './coil100/coil-100/coil-100/obj8__75.png',
#  './coil100/coil-100/coil-100/obj39__55.png',
#  './coil100/coil-100/coil-100/obj22__125.png',
#  './coil100/coil-100/coil-100/obj7__210.png',
#  './coil100/coil-100/coil-100/obj59__335.png',
#  './coil100/coil-100/coil-100/obj72__145.png',
#  './coil100/coil-100/coil-100/obj25__315.png',
#  './coil100/coil-100/coil-100/obj32__280.png',
#  './coil100/coil-100/coil-100/obj17__315.png',
#  './coil100/coil-100/coil-100/obj53__330.png',
#  './coil100/coil-100/coil-100/obj72__55.png',
#  './coil100/coil-100/coil-100/obj50__225.png',
#  './coil100/coil-100/coil-100/obj18__145.png',
#  './coil100/coil-100/coil-100/obj81__150.png',
#  './coil100/coil-100/coil-100/obj2__105.png',
#  './coil100/coil-100/coil-100/obj34__330.png',
#  './coil100/coil-100/coil-100/obj43__210.png',
#  './coil100/coil-100/coil-100/obj36__140.png',
#  './coil100/coil-100/coil-100/obj52__120.png',
#  './coil100/coil-100/coil-100/obj91__300.png',
#  './coil100/coil-100/coil-100/obj57__95.png',
#  './coil100/coil-100/coil-100/obj62__350.png',
#  './coil100/coil-100/coil-100/obj55__255.png',
#  './coil100/coil-100/coil-100/obj55__205.png',
#  './coil100/coil-100/coil-100/obj41__285.png',
#  './coil100/coil-100/coil-100/obj62__145.png',
#  './coil100/coil-100/coil-100/obj24__230.png',
#  './coil100/coil-100/coil-100/obj64__265.png',
#  './coil100/coil-100/coil-100/obj93__80.png',
#  './coil100/coil-100/coil-100/obj47__55.png',
#  './coil100/coil-100/coil-100/obj35__310.png',
#  './coil100/coil-100/coil-100/obj93__290.png',
#  './coil100/coil-100/coil-100/obj63__135.png',
#  './coil100/coil-100/coil-100/obj78__115.png',
#  './coil100/coil-100/coil-100/obj53__235.png',
#  './coil100/coil-100/coil-100/obj31__125.png',
#  './coil100/coil-100/coil-100/obj57__280.png',
#  './coil100/coil-100/coil-100/obj62__165.png',
#  './coil100/coil-100/coil-100/obj53__215.png',
#  './coil100/coil-100/coil-100/obj74__235.png',
#  './coil100/coil-100/coil-100/obj21__345.png',
#  './coil100/coil-100/coil-100/obj97__0.png',
#  './coil100/coil-100/coil-100/obj31__95.png',
#  './coil100/coil-100/coil-100/obj78__165.png',
#  './coil100/coil-100/coil-100/obj12__200.png',
#  './coil100/coil-100/coil-100/obj91__230.png',
#  './coil100/coil-100/coil-100/obj81__285.png',
#  './coil100/coil-100/coil-100/obj31__240.png',
#  './coil100/coil-100/coil-100/obj12__0.png',
#  './coil100/coil-100/coil-100/obj85__260.png',
#  './coil100/coil-100/coil-100/obj95__30.png',
#  './coil100/coil-100/coil-100/obj26__55.png',
#  './coil100/coil-100/coil-100/obj26__0.png',
#  './coil100/coil-100/coil-100/obj67__200.png',
#  './coil100/coil-100/coil-100/obj11__225.png',
#  './coil100/coil-100/coil-100/obj79__110.png',
#  './coil100/coil-100/coil-100/obj85__220.png',
#  './coil100/coil-100/coil-100/obj10__110.png',
#  './coil100/coil-100/coil-100/obj97__10.png',
#  './coil100/coil-100/coil-100/obj25__270.png',
#  './coil100/coil-100/coil-100/obj71__130.png',
#  './coil100/coil-100/coil-100/obj29__270.png',
#  './coil100/coil-100/coil-100/obj10__215.png',
#  './coil100/coil-100/coil-100/obj56__65.png',
#  './coil100/coil-100/coil-100/obj17__25.png',
#  './coil100/coil-100/coil-100/obj80__175.png',
#  './coil100/coil-100/coil-100/obj27__95.png',
#  './coil100/coil-100/coil-100/obj54__165.png',
#  './coil100/coil-100/coil-100/obj19__235.png',
#  './coil100/coil-100/coil-100/obj55__160.png',
#  './coil100/coil-100/coil-100/obj6__40.png',
#  './coil100/coil-100/coil-100/obj23__70.png',
#  './coil100/coil-100/coil-100/obj51__60.png',
#  './coil100/coil-100/coil-100/obj55__30.png',
#  './coil100/coil-100/coil-100/obj43__175.png',
#  './coil100/coil-100/coil-100/obj94__190.png',
#  './coil100/coil-100/coil-100/obj29__150.png',
#  './coil100/coil-100/coil-100/obj57__100.png',
#  './coil100/coil-100/coil-100/obj5__165.png',
#  './coil100/coil-100/coil-100/obj15__205.png',
#  './coil100/coil-100/coil-100/obj42__25.png',
#  './coil100/coil-100/coil-100/obj52__110.png',
#  './coil100/coil-100/coil-100/obj40__265.png',
#  './coil100/coil-100/coil-100/obj54__275.png',
#  './coil100/coil-100/coil-100/obj89__50.png',
#  './coil100/coil-100/coil-100/obj66__100.png',
#  './coil100/coil-100/coil-100/obj85__125.png',
#  './coil100/coil-100/coil-100/obj46__325.png',
#  './coil100/coil-100/coil-100/obj1__250.png',
#  './coil100/coil-100/coil-100/obj22__315.png',
#  './coil100/coil-100/coil-100/obj33__235.png',
#  './coil100/coil-100/coil-100/obj62__110.png',
#  './coil100/coil-100/coil-100/obj12__175.png',
#  './coil100/coil-100/coil-100/obj98__30.png',
#  './coil100/coil-100/coil-100/obj10__135.png',
#  './coil100/coil-100/coil-100/obj38__235.png',
#  './coil100/coil-100/coil-100/obj42__160.png',
#  './coil100/coil-100/coil-100/obj4__75.png',
#  './coil100/coil-100/coil-100/obj66__170.png',
#  './coil100/coil-100/coil-100/obj27__105.png',
#  './coil100/coil-100/coil-100/obj79__225.png',
#  './coil100/coil-100/coil-100/obj40__170.png',
#  './coil100/coil-100/coil-100/obj9__155.png',
#  './coil100/coil-100/coil-100/obj29__25.png',
#  './coil100/coil-100/coil-100/obj78__180.png',
#  './coil100/coil-100/coil-100/obj82__70.png',
#  './coil100/coil-100/coil-100/obj30__255.png',
#  './coil100/coil-100/coil-100/obj100__295.png',
#  './coil100/coil-100/coil-100/obj4__305.png',
#  './coil100/coil-100/coil-100/obj99__125.png',
#  './coil100/coil-100/coil-100/obj6__70.png',
#  './coil100/coil-100/coil-100/obj8__260.png',
#  './coil100/coil-100/coil-100/obj7__170.png',
#  './coil100/coil-100/coil-100/obj56__10.png',
#  './coil100/coil-100/coil-100/obj61__245.png',
#  './coil100/coil-100/coil-100/obj37__160.png',
#  './coil100/coil-100/coil-100/obj57__85.png',
#  './coil100/coil-100/coil-100/obj29__75.png',
#  './coil100/coil-100/coil-100/obj73__295.png',
#  './coil100/coil-100/coil-100/obj33__85.png',
#  './coil100/coil-100/coil-100/obj2__160.png',
#  './coil100/coil-100/coil-100/obj96__205.png',
#  './coil100/coil-100/coil-100/obj34__310.png',
#  './coil100/coil-100/coil-100/obj34__75.png',
#  './coil100/coil-100/coil-100/obj36__210.png',
#  './coil100/coil-100/coil-100/obj74__10.png',
#  './coil100/coil-100/coil-100/obj100__150.png',
#  './coil100/coil-100/coil-100/obj90__50.png',
#  './coil100/coil-100/coil-100/obj86__205.png',
#  './coil100/coil-100/coil-100/obj5__10.png',
#  './coil100/coil-100/coil-100/obj70__305.png',
#  './coil100/coil-100/coil-100/obj59__310.png',
#  './coil100/coil-100/coil-100/obj52__240.png',
#  './coil100/coil-100/coil-100/obj42__20.png',
#  './coil100/coil-100/coil-100/obj3__220.png',
#  './coil100/coil-100/coil-100/obj88__260.png',
#  './coil100/coil-100/coil-100/obj18__80.png',
#  './coil100/coil-100/coil-100/obj64__145.png',
#  './coil100/coil-100/coil-100/obj57__80.png',
#  './coil100/coil-100/coil-100/obj71__140.png',
#  './coil100/coil-100/coil-100/obj63__60.png',
#  './coil100/coil-100/coil-100/obj50__240.png',
#  './coil100/coil-100/coil-100/obj55__75.png',
#  './coil100/coil-100/coil-100/obj42__55.png',
#  './coil100/coil-100/coil-100/obj18__260.png',
#  './coil100/coil-100/coil-100/obj45__175.png',
#  './coil100/coil-100/coil-100/obj99__75.png',
#  './coil100/coil-100/coil-100/obj17__245.png',
#  './coil100/coil-100/coil-100/obj77__115.png',
#  './coil100/coil-100/coil-100/obj81__250.png',
#  './coil100/coil-100/coil-100/obj6__140.png',
#  './coil100/coil-100/coil-100/obj69__220.png',
#  './coil100/coil-100/coil-100/obj49__50.png',
#  './coil100/coil-100/coil-100/obj61__130.png',
#  './coil100/coil-100/coil-100/obj96__115.png',
#  './coil100/coil-100/coil-100/obj77__245.png',
#  './coil100/coil-100/coil-100/obj51__230.png',
#  './coil100/coil-100/coil-100/obj75__110.png',
#  './coil100/coil-100/coil-100/obj13__135.png',
#  './coil100/coil-100/coil-100/obj1__45.png',
#  './coil100/coil-100/coil-100/obj81__60.png',
#  './coil100/coil-100/coil-100/obj51__305.png',
#  './coil100/coil-100/coil-100/obj33__110.png',
#  './coil100/coil-100/coil-100/obj61__35.png',
#  './coil100/coil-100/coil-100/obj86__85.png',
#  './coil100/coil-100/coil-100/obj82__225.png',
#  './coil100/coil-100/coil-100/obj98__105.png',
#  './coil100/coil-100/coil-100/obj34__320.png',
#  './coil100/coil-100/coil-100/obj9__75.png',
#  './coil100/coil-100/coil-100/obj33__220.png',
#  './coil100/coil-100/coil-100/obj77__95.png',
#  './coil100/coil-100/coil-100/obj83__275.png',
#  './coil100/coil-100/coil-100/obj87__285.png',
#  './coil100/coil-100/coil-100/obj81__340.png',
#  './coil100/coil-100/coil-100/obj39__330.png',
#  './coil100/coil-100/coil-100/obj29__215.png',
#  './coil100/coil-100/coil-100/obj1__345.png',
#  './coil100/coil-100/coil-100/obj58__230.png',
#  './coil100/coil-100/coil-100/obj52__140.png',
#  './coil100/coil-100/coil-100/obj69__285.png',
#  './coil100/coil-100/coil-100/obj87__35.png',
#  './coil100/coil-100/coil-100/obj50__125.png',
#  './coil100/coil-100/coil-100/obj82__160.png',
#  './coil100/coil-100/coil-100/obj56__130.png',
#  './coil100/coil-100/coil-100/obj28__65.png',
#  './coil100/coil-100/coil-100/obj10__20.png',
#  './coil100/coil-100/coil-100/obj31__155.png',
#  './coil100/coil-100/coil-100/obj69__20.png',
#  './coil100/coil-100/coil-100/obj77__75.png',
#  './coil100/coil-100/coil-100/obj51__190.png',
#  './coil100/coil-100/coil-100/obj20__10.png',
#  './coil100/coil-100/coil-100/obj86__270.png',
#  './coil100/coil-100/coil-100/obj21__90.png',
#  './coil100/coil-100/coil-100/obj33__255.png',
#  './coil100/coil-100/coil-100/obj81__145.png',
#  './coil100/coil-100/coil-100/obj2__290.png',
#  './coil100/coil-100/coil-100/obj79__190.png',
#  './coil100/coil-100/coil-100/obj45__220.png',
#  './coil100/coil-100/coil-100/obj58__275.png',
#  './coil100/coil-100/coil-100/obj14__0.png',
#  './coil100/coil-100/coil-100/obj77__215.png',
#  './coil100/coil-100/coil-100/obj45__240.png',
#  './coil100/coil-100/coil-100/obj47__270.png',
#  './coil100/coil-100/coil-100/obj5__110.png',
#  './coil100/coil-100/coil-100/obj11__345.png',
#  './coil100/coil-100/coil-100/obj98__130.png',
#  './coil100/coil-100/coil-100/obj84__15.png',
#  './coil100/coil-100/coil-100/obj14__100.png',
#  './coil100/coil-100/coil-100/obj96__65.png',
#  './coil100/coil-100/coil-100/obj36__215.png',
#  './coil100/coil-100/coil-100/obj31__330.png',
#  './coil100/coil-100/coil-100/obj54__180.png',
#  './coil100/coil-100/coil-100/obj40__115.png',
#  './coil100/coil-100/coil-100/obj27__90.png',
#  './coil100/coil-100/coil-100/obj98__125.png',
#  './coil100/coil-100/coil-100/obj21__5.png',
#  './coil100/coil-100/coil-100/obj36__105.png',
#  './coil100/coil-100/coil-100/obj69__40.png',
#  './coil100/coil-100/coil-100/obj14__145.png',
#  './coil100/coil-100/coil-100/obj86__210.png',
#  './coil100/coil-100/coil-100/obj94__155.png',
#  './coil100/coil-100/coil-100/obj90__155.png',
#  './coil100/coil-100/coil-100/obj86__255.png',
#  './coil100/coil-100/coil-100/obj64__255.png',
#  './coil100/coil-100/coil-100/obj93__190.png',
#  './coil100/coil-100/coil-100/obj36__265.png',
#  './coil100/coil-100/coil-100/obj26__225.png',
#  './coil100/coil-100/coil-100/obj39__240.png',
#  './coil100/coil-100/coil-100/obj30__145.png',
#  './coil100/coil-100/coil-100/obj91__330.png',
#  './coil100/coil-100/coil-100/obj76__25.png',
#  './coil100/coil-100/coil-100/obj87__115.png',
#  './coil100/coil-100/coil-100/obj27__220.png',
#  './coil100/coil-100/coil-100/obj61__30.png',
#  './coil100/coil-100/coil-100/obj22__5.png',
#  './coil100/coil-100/coil-100/obj43__30.png',
#  './coil100/coil-100/coil-100/obj28__5.png',
#  './coil100/coil-100/coil-100/obj84__260.png',
#  './coil100/coil-100/coil-100/obj70__220.png',
#  './coil100/coil-100/coil-100/obj3__290.png',
#  './coil100/coil-100/coil-100/obj98__280.png',
#  './coil100/coil-100/coil-100/obj65__115.png',
#  './coil100/coil-100/coil-100/obj79__355.png',
#  './coil100/coil-100/coil-100/obj20__320.png',
#  './coil100/coil-100/coil-100/obj79__50.png',
#  './coil100/coil-100/coil-100/obj21__260.png',
#  './coil100/coil-100/coil-100/obj26__250.png',
#  './coil100/coil-100/coil-100/obj13__345.png',
#  './coil100/coil-100/coil-100/obj92__195.png',
#  './coil100/coil-100/coil-100/obj76__170.png',
#  './coil100/coil-100/coil-100/obj32__45.png',
#  './coil100/coil-100/coil-100/obj62__120.png',
#  './coil100/coil-100/coil-100/obj63__90.png',
#  './coil100/coil-100/coil-100/obj88__195.png',
#  './coil100/coil-100/coil-100/obj71__5.png',
#  './coil100/coil-100/coil-100/obj69__280.png',
#  './coil100/coil-100/coil-100/obj23__60.png',
#  './coil100/coil-100/coil-100/obj7__205.png',
#  './coil100/coil-100/coil-100/obj84__265.png',
#  './coil100/coil-100/coil-100/obj9__335.png',
#  './coil100/coil-100/coil-100/obj16__345.png',
#  './coil100/coil-100/coil-100/obj38__200.png',
#  './coil100/coil-100/coil-100/obj45__285.png',
#  './coil100/coil-100/coil-100/obj1__240.png',
#  './coil100/coil-100/coil-100/obj57__140.png',
#  './coil100/coil-100/coil-100/obj100__235.png',
#  './coil100/coil-100/coil-100/obj6__180.png',
#  './coil100/coil-100/coil-100/obj63__15.png',
#  './coil100/coil-100/coil-100/obj2__70.png',
#  './coil100/coil-100/coil-100/obj27__345.png',
#  './coil100/coil-100/coil-100/obj43__305.png',
#  './coil100/coil-100/coil-100/obj32__245.png',
#  './coil100/coil-100/coil-100/obj3__130.png',
#  './coil100/coil-100/coil-100/obj12__110.png',
#  './coil100/coil-100/coil-100/obj70__135.png',
#  './coil100/coil-100/coil-100/obj65__200.png',
#  './coil100/coil-100/coil-100/obj24__170.png',
#  './coil100/coil-100/coil-100/obj42__145.png',
#  './coil100/coil-100/coil-100/obj80__315.png',
#  './coil100/coil-100/coil-100/obj67__320.png',
#  './coil100/coil-100/coil-100/obj21__195.png',
#  './coil100/coil-100/coil-100/obj14__170.png',
#  './coil100/coil-100/coil-100/obj43__275.png',
#  './coil100/coil-100/coil-100/obj76__310.png',
#  './coil100/coil-100/coil-100/obj84__185.png',
#  './coil100/coil-100/coil-100/obj31__15.png',
#  './coil100/coil-100/coil-100/obj71__135.png',
#  './coil100/coil-100/coil-100/obj98__190.png',
#  './coil100/coil-100/coil-100/obj36__235.png',
#  './coil100/coil-100/coil-100/obj59__270.png',
#  './coil100/coil-100/coil-100/obj9__105.png',
#  './coil100/coil-100/coil-100/obj38__120.png',
#  './coil100/coil-100/coil-100/obj1__120.png',
#  './coil100/coil-100/coil-100/obj71__35.png',
#  './coil100/coil-100/coil-100/obj60__260.png',
#  './coil100/coil-100/coil-100/obj19__265.png',
#  './coil100/coil-100/coil-100/obj20__210.png',
#  './coil100/coil-100/coil-100/obj14__275.png',
#  './coil100/coil-100/coil-100/obj59__245.png',
#  './coil100/coil-100/coil-100/obj80__65.png',
#  './coil100/coil-100/coil-100/obj9__305.png',
#  './coil100/coil-100/coil-100/obj61__50.png',
#  './coil100/coil-100/coil-100/obj16__35.png',
#  './coil100/coil-100/coil-100/obj5__5.png',
#  './coil100/coil-100/coil-100/obj79__330.png',
#  './coil100/coil-100/coil-100/obj57__240.png',
#  './coil100/coil-100/coil-100/obj87__45.png',
#  './coil100/coil-100/coil-100/obj40__205.png',
#  './coil100/coil-100/coil-100/obj12__335.png',
#  './coil100/coil-100/coil-100/obj44__50.png',
#  './coil100/coil-100/coil-100/obj58__50.png',
#  './coil100/coil-100/coil-100/obj60__195.png',
#  './coil100/coil-100/coil-100/obj85__355.png',
#  './coil100/coil-100/coil-100/obj37__40.png',
#  './coil100/coil-100/coil-100/obj41__95.png',
#  './coil100/coil-100/coil-100/obj86__10.png',
#  './coil100/coil-100/coil-100/obj56__5.png',
#  './coil100/coil-100/coil-100/obj68__290.png',
#  './coil100/coil-100/coil-100/obj14__110.png',
#  './coil100/coil-100/coil-100/obj74__265.png',
#  './coil100/coil-100/coil-100/obj15__330.png',
#  './coil100/coil-100/coil-100/obj43__300.png',
#  './coil100/coil-100/coil-100/obj83__240.png',
#  './coil100/coil-100/coil-100/obj83__40.png',
#  './coil100/coil-100/coil-100/obj31__115.png',
#  './coil100/coil-100/coil-100/obj15__65.png',
#  './coil100/coil-100/coil-100/obj21__220.png',
#  './coil100/coil-100/coil-100/obj52__95.png',
#  './coil100/coil-100/coil-100/obj18__0.png',
#  './coil100/coil-100/coil-100/obj60__350.png',
#  './coil100/coil-100/coil-100/obj7__345.png',
#  './coil100/coil-100/coil-100/obj75__165.png',
#  './coil100/coil-100/coil-100/obj6__260.png',
#  './coil100/coil-100/coil-100/obj69__245.png',
#  './coil100/coil-100/coil-100/obj59__300.png',
#  './coil100/coil-100/coil-100/obj88__330.png',
#  './coil100/coil-100/coil-100/obj75__20.png',
#  './coil100/coil-100/coil-100/obj36__100.png',
#  './coil100/coil-100/coil-100/obj77__120.png',
#  './coil100/coil-100/coil-100/obj36__230.png',
#  './coil100/coil-100/coil-100/obj60__320.png',
#  './coil100/coil-100/coil-100/obj63__120.png',
#  './coil100/coil-100/coil-100/obj38__270.png',
#  './coil100/coil-100/coil-100/obj29__305.png',
#  './coil100/coil-100/coil-100/obj72__80.png',
#  './coil100/coil-100/coil-100/obj67__295.png',
#  './coil100/coil-100/coil-100/obj60__105.png',
#  './coil100/coil-100/coil-100/obj69__160.png',
#  './coil100/coil-100/coil-100/obj70__130.png',
#  './coil100/coil-100/coil-100/obj41__100.png',
#  './coil100/coil-100/coil-100/obj82__325.png',
#  './coil100/coil-100/coil-100/obj10__190.png',
#  './coil100/coil-100/coil-100/obj33__130.png',
#  './coil100/coil-100/coil-100/obj19__45.png',
#  './coil100/coil-100/coil-100/obj84__65.png',
#  './coil100/coil-100/coil-100/obj22__115.png',
#  './coil100/coil-100/coil-100/obj89__350.png',
#  './coil100/coil-100/coil-100/obj53__325.png',
#  './coil100/coil-100/coil-100/obj75__170.png',
#  './coil100/coil-100/coil-100/obj19__135.png',
#  './coil100/coil-100/coil-100/obj62__290.png',
#  './coil100/coil-100/coil-100/obj2__265.png',
#  './coil100/coil-100/coil-100/obj34__270.png',
#  './coil100/coil-100/coil-100/obj28__90.png',
#  './coil100/coil-100/coil-100/obj68__80.png',
#  './coil100/coil-100/coil-100/obj80__85.png',
#  './coil100/coil-100/coil-100/obj97__125.png',
#  './coil100/coil-100/coil-100/obj40__255.png',
#  './coil100/coil-100/coil-100/obj7__245.png',
#  './coil100/coil-100/coil-100/obj70__165.png',
#  './coil100/coil-100/coil-100/obj20__325.png',
#  './coil100/coil-100/coil-100/obj49__275.png',
#  './coil100/coil-100/coil-100/obj68__5.png',
#  './coil100/coil-100/coil-100/obj3__285.png',
#  './coil100/coil-100/coil-100/obj61__180.png',
#  './coil100/coil-100/coil-100/obj42__300.png',
#  './coil100/coil-100/coil-100/obj47__210.png',
#  './coil100/coil-100/coil-100/obj65__285.png',
#  './coil100/coil-100/coil-100/obj44__200.png',
#  ...]

# %%
from PIL import Image, ImageStat


#preparing data set
class Coil100_DataSet(Dataset):
  def __init__(self,label_list, root,transform=None):
    self.data_frame =label_list
    self.transform =transform
    self.root_dir =root


  def __len__(self):
    return len(self.data_frame)

  def __getitem__(self, index):
    row = self.data_frame[index]
    image_id, image_label = row[0], row[1] -1
    image_name = self.root_dir + "/" + str(image_id)
    img= Image.open(image_name)
    if self.transform:
      img = self.transform(img)
    return img, image_label

# %%
import torchvision.transforms as transforms

dataset = Image_datasets(labels, data_direct, transform=transforms.ToTensor())
len(dataset)
# Out:
# 7200

# %%
img, label = dataset[42]
print(img.shape, label)
img
# Out:
# torch.Size([3, 128, 128]) 57
# tensor([[[0.2078, 0.2078, 0.1020,  ..., 0.1020, 0.1020, 0.1020],
#          [0.1020, 0.1020, 0.1020,  ..., 0.1020, 0.1020, 0.1020],
#          [0.1020, 0.1020, 0.1020,  ..., 0.1020, 0.1020, 0.1020],
#          ...,
#          [0.1020, 0.1020, 0.1020,  ..., 0.1020, 0.1020, 0.1020],
#          [0.1020, 0.1020, 0.1020,  ..., 0.1020, 0.1020, 0.1020],
#          [0.1020, 0.1020, 0.1020,  ..., 0.1020, 0.1020, 0.1020]],
#
#         [[0.2000, 0.2000, 0.1020,  ..., 0.1020, 0.1020, 0.1020],
#          [0.1020, 0.1020, 0.1020,  ..., 0.1020, 0.1020, 0.1020],
#          [0.1020, 0.1020, 0.1020,  ..., 0.1020, 0.1020, 0.1020],
#          ...,
#          [0.1020, 0.1020, 0.1020,  ..., 0.1020, 0.1020, 0.1020],
#          [0.1020, 0.1020, 0.1020,  ..., 0.1020, 0.1020, 0.1020],
#          [0.1020, 0.1020, 0.1020,  ..., 0.1020, 0.1020, 0.1020]],
#
#         [[0.1255, 0.0392, 0.1020,  ..., 0.1020, 0.1020, 0.1020],
#          [0.1020, 0.1020, 0.1020,  ..., 0.1020, 0.1020, 0.1020],
#          [0.1020, 0.1020, 0.1020,  ..., 0.1020, 0.1020, 0.1020],
#          ...,
#          [0.1020, 0.1020, 0.1020,  ..., 0.1020, 0.1020, 0.1020],
#          [0.1020, 0.1020, 0.1020,  ..., 0.1020, 0.1020, 0.1020],
#          [0.1020, 0.1020, 0.1020,  ..., 0.1020, 0.1020, 0.1020]]])

# %%
random_seed =42
torch.manual_seed(random_seed)

# %%
input_channel =3 #rgb image
input_size= 3*128 *128
num_class=101

# %%
batch_size =100
val_size=720
test_size=720
train_size=5760

train_data, val_data, test_data =random_split(dataset,[train_size, val_size, test_size])
print(f"size of train data : {len(train_data)}")
print(f"size of train data : {len(val_data)}")
# Out:
# size of train data : 5760
# size of train data : 720

# %%
train_data_load =DataLoader(train_data, batch_size, shuffle=True, num_workers=2, pin_memory=True)
val_data_load =DataLoader(val_data, batch_size, shuffle=True, num_workers=2, pin_memory=True)
test_data_load =DataLoader(test_data, batch_size, shuffle=True, num_workers=2, pin_memory=True)

# %%
from torchvision.utils import make_grid
import matplotlib.pyplot as plt

def batch(dataload):
  for image, label in dataload:
    fig,ax =  plt.subplots(figsize = (10,10))
    ax.set_xticks([])
    ax.set_yticks([])
    ax.imshow(make_grid(image,nrow=10).permute(1,2,0))
    break

batch(train_data_load)

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
def accuracy(outputs, labels):
    _,preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

# %%
class ImageClassificationBase(nn.Module):

    def training_step(self, batch):
        images, labels = batch
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss

    def validation_step(self, batch):
        images, labels = batch
        out = self(images)                    # Generate predictions
        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}

    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}

    def epoch_end(self, epoch, result):
        print("Epoch [{}], train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['train_loss'], result['val_loss'], result['val_acc']))

# %%
class Coil_100_Model(ImageClassificationBase):
    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(

            nn.Conv2d(input_channel, 32, kernel_size = 3, padding = 1),
            nn.ReLU(),
            nn.Conv2d(32,64, kernel_size = 3, stride = 1, padding = 1),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.BatchNorm2d(64),

            nn.Conv2d(64, 128, kernel_size = 3, stride = 1, padding = 1),
            nn.ReLU(),
            nn.Conv2d(128 ,256, kernel_size = 3, stride = 1, padding = 1),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.BatchNorm2d(256),


            nn.Flatten(),
            nn.Linear(256*1024,1024),
            nn.ReLU(),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Linear(512,num_class)
        )

    def forward(self, xb):
        return self.network(xb)

# %%
model_coil100=Coil_100_Model()
model_coil100
# Out:
# Coil_100_Model(
#   (network): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): Flatten(start_dim=1, end_dim=-1)
#     (13): Linear(in_features=262144, out_features=1024, bias=True)
#     (14): ReLU()
#     (15): Linear(in_features=1024, out_features=512, bias=True)
#     (16): ReLU()
#     (17): Linear(in_features=512, out_features=101, bias=True)
#   )
# )

# %%
def get_default_device():
   if torch.cuda.is_available():
        return torch.device('cuda')
   else:
        return torch.device('cpu')

def to_device(data, device):
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
   def __init__(self, dl, device):
        self.dl = dl
        self.device = device

   def __iter__(self):
       for b in self.dl:
            yield to_device(b, self.device)

   def __len__(self):
        return len(self.dl)

device = get_default_device()

# %%
train_data_load = DeviceDataLoader(train_data_load, device)
val_data_load = DeviceDataLoader(val_data_load, device)
test_data_load = DeviceDataLoader(test_data_load, device)
to_device(model_coil100, device);

# %%
@torch.no_grad()
def evaluate(model, val_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)


def fit(epochs, lr, model, train_loader, val_loader, opt_func = torch.optim.SGD):

    history = []
    optimizer = opt_func(model.parameters(),lr)
    for epoch in range(epochs):

        model.train()
        train_losses = []
        for batch in train_loader:
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        model.epoch_end(epoch, result)
        history.append(result)

    return history

# %%
model_coil100 = to_device(Coil_100_Model(), device)

# %%
evaluate(model_coil100, val_data_load)
# Out:
# {'val_loss': 4.615428447723389, 'val_acc': 0.016249999403953552}

# %%
num_epochs = 5
opt_func = torch.optim.Adam
learning_rate=0.001

# %%
result = fit(num_epochs, learning_rate, model_coil100, train_data_load, val_data_load, opt_func)
# Out:
# Epoch [0], train_loss: 2.3503, val_loss: 1.6756, val_acc: 0.5262
# Epoch [1], train_loss: 0.1198, val_loss: 0.0945, val_acc: 0.9737
# Epoch [2], train_loss: 0.0576, val_loss: 0.0345, val_acc: 0.9962
# Epoch [3], train_loss: 0.0583, val_loss: 0.1400, val_acc: 0.9688
# Epoch [4], train_loss: 0.0828, val_loss: 0.5492, val_acc: 0.9125

# %%
def plot_accuracies(result):
    accuracies = [x['val_acc'] for x in result]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs. No. of epochs');

# %%
plot_accuracies(result)

# %%
def plot_losses(result):
    train_losses = [x.get('train_loss') for x in result]
    val_losses = [x['val_loss'] for x in result]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. No. of epochs');

# %%
plot_losses(result)

# %%
def predict_image(img, model):
    # Convert to a batch of 1
    xb = to_device(img.unsqueeze(0), device)
    # Get predictions from model
    yb = model(xb)
    # Pick index with highest probability
    _, preds  = torch.max(yb, dim=1)
    # Retrieve the class label
    return preds[0].item()

# %%
img, label = test_data[57]
plt.imshow(img.permute(1, 2, 0))
print('Label:', label, ', Predicted:', predict_image(img, model_coil100))
# Out:
# Label: 11 , Predicted: 11

# %%
# !pip install -q gradio torch torchvision

# %%
import gradio as gr
import numpy as np
from PIL import Image
import torch
from torchvision import transforms

# %%
# Funcția pentru a face predicții pe o imagine
def classify_image(inp):
    # Conversia imaginii din format numpy array la format PIL Image
    img_pil = Image.fromarray(np.uint8(inp))

    # Transformările necesare pentru a prelucra imaginea și a o da modelului
    transform = transforms.Compose([
        transforms.Resize((128, 128)),
        transforms.ToTensor(),
    ])

    img_tensor = transform(img_pil).unsqueeze(0)  # Adaugă dimensiunea batch (1, C, H, W)

    # Asigură-te că modelul și tensorul sunt pe același dispozitiv (CPU sau GPU)
    global model_coil100  # Utilizăm referința globală la model_coil100
    model_coil100 = model_coil100.to(img_tensor.device)
    img_tensor = img_tensor.to(img_tensor.device)

    # Treci tensorul prin model pentru a face predicția
    with torch.no_grad():
        model_coil100.eval()
        output = model_coil100(img_tensor)

    # Procesează rezultatul pentru a obține clasa prezisă
    _, predicted_class = torch.max(output, 1)

    # Întoarce rezultatul sub formă de dicționar
    return {f"Clasa {predicted_class.item()}": 1.0}

image = gr.inputs.Image(shape=(128, 128))
label = gr.outputs.Label(num_top_classes=1)

gui = gr.Interface(fn=classify_image, inputs=image, outputs=label, capture_session=True).launch(debug=True, share=True)
gui.launch()
# Out:
# <ipython-input-200-a662950d3ec9>:30: GradioDeprecationWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   image = gr.inputs.Image(shape=(128, 128))
# <ipython-input-200-a662950d3ec9>:30: GradioDeprecationWarning: `optional` parameter is deprecated, and it has no effect
#   image = gr.inputs.Image(shape=(128, 128))
# <ipython-input-200-a662950d3ec9>:31: GradioDeprecationWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   label = gr.outputs.Label(num_top_classes=1)
# <ipython-input-200-a662950d3ec9>:31: GradioUnusedKwargWarning: You have unused kwarg parameters in Label, please remove them: {'type': 'auto'}
#   label = gr.outputs.Label(num_top_classes=1)
# <ipython-input-200-a662950d3ec9>:33: GradioDeprecationWarning: `capture_session` parameter is deprecated, and it has no effect
#   gui = gr.Interface(fn=classify_image, inputs=image, outputs=label, capture_session=True).launch(debug=True, share=True)
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://18fe8d487c8ba67428.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://18fe8d487c8ba67428.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
